# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
noise_scale = 100
number_of_samples = 50
x_sample = 25*(np.random.rand(number_of_samples) - 0.8);
x = np.sort(x_sample)
y = 5 * x + 20 * x**2 + 1 * x**3 + noise_scale*np.random.randn(number_of_samples);

# %%
point = []
for i in range(len(x)):
    point.append((x[i],y[i]))

array = np.random.randint(0,15,(100,6))
count = 0
for count in range(1000):
    badness = []
    for i in range(len(array)):
        badness1 = 0
        for j in range(len(point)):
            y = point[j][1]
            a = point[j][0]
            y_predict = array[i][0]*a**5 + array[i][1]*a**4 + array[i][2]*a**3 + array[i][3]*a**2 + array[i][4]*a + array[i][5]
            badness1 += (y-y_predict)**2
        badness.append(badness1)    
    minbadness = []
    m = np.argsort(badness)
    new_array = []
    for i in range(10):
        new_array.append(array[m[i]])
        minbadness.append(badness[m[i]])
    if(count < 999):
        for i in range(10):
            for j in range(9):
                index = np.random.randint(0,6)
                num = np.random.uniform(0,2)
                new_array1 = [0,0,0,0,0,0]
                for k in range(6):
                    if k == index:
                        new_array1[k] = new_array[i][k]*num
                    else:
                        new_array1[k] = new_array[i][k]  
                new_array.append(new_array1)
        a = np.array(new_array)
        b = a.tolist()
        array = b
        count += 1
    else:
        print(new_array)
        print(minbadness)
# Out:
# [[0.0, 2.587787758177931e-32, 0.7350911919530994, 14.68445394450272, 1.492242283009226e-55, 117.46787085486456], [0.0, 2.493040865547785e-33, 0.7350911919530994, 14.68445394450272, 2.1294101816088005e-55, 117.46787085486456], [0.0, 2.493040865547785e-33, 0.7350911919530994, 14.68445394450272, 2.1294101816088005e-55, 117.46787085486456], [0.0, 2.844667227758623e-33, 0.7350911919530994, 14.68445394450272, 1.1931197268786387e-55, 117.46787085486456], [0.0, 2.493040865547785e-33, 0.7350911919530994, 14.68445394450272, 1.9986342351603224e-55, 117.46787085486456], [0.0, 4.48912626209394e-33, 0.7350911919530994, 14.68445394450272, 1.492242283009226e-55, 117.46787085486456], [0.0, 4.48912626209394e-33, 0.7350911919530994, 14.68445394450272, 1.9444744322289516e-55, 117.46787085486456], [0.0, 1.5003873333294737e-33, 0.7350911919530994, 14.68445394450272, 2.094523819368917e-55, 117.46787085486456], [0.0, 6.802111371204454e-34, 0.7350911919530994, 14.68445394450272, 2.094523819368917e-55, 117.46
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
noise_scale = 100
number_of_samples = 50
x_sample = 25*(np.random.rand(number_of_samples) - 0.8);
x = np.sort(x_sample)
y = 5 * x + 20 * x**2 + 1 * x**3 + noise_scale*np.random.randn(number_of_samples);
best = new_array[0]
x_2 = np.arange(-50,50)
y_2 = best[0]*x**5 + best[1]*x**4 +best[2]*x**3 + best[3]*x**2 + best[4]*x + best[5]
a = np.polyfit(x,y,3);
b = np.poly1d(a);
plt.plot(x,y,'o',x,b(x),'-')

plt.plot(x,y_2,'y-')
plt.show()
